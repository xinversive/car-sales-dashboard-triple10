# %% [markdown]
# # 📊 Exploratory Data Analysis: Used Car Sales
#
# This notebook performs basic exploratory data analysis on a dataset of used vehicle listings.
# The goal is to identify patterns in pricing and mileage, detect duplicates, and provide visual insights that support the final dashboard.

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"

# load the dataset
df = pd.read_csv(r'C:\Users\INVERSE\car-sales-dashboard-triple10\vehicles_us.csv')

# %%
# price distribution
px.histogram(df, x='price')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="748b29da-8794-4463-abde-23e90dd91376" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("748b29da-8794-4463-abde-23e90dd91376")) {                    Plotly.newPlot(                        "748b29da-8794-4463-abde-23e90dd91376",                        [{"bingroup":"x","hovertemplate":"price=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"x":{"dtype":"i4","bdata":"uCQAAJxjAAB8FQAA3AUAADQ6AACOOgAAvjIAAHY+AADsLAAA8CMAACxMAAAeIwAALkoAAHRAAAC+MgAARkYAAI46AACmNgAA1DAAAKY2AABOGwAAghQAAEwdAABMHQAAbg8AAOssAAAzIQAAxzIAAGh0AAB3FQAAiBMAAN8uAAAbJQAAMg8AABwlAACXOgAAAykAAEwdAAA\\...\\u002fOgAAw1AAANtMAACTOgAAQTYAAIgTAADUFwAAsgwAAChuAAAcPgAAVIgAAIJZAAB0WQAAvE0AAF05AAAlYQAAf1cAAN4mAADjQwAAbxcAACQTAACbDwAAlCoAAFMbAACsDQAAD6QAAJ+MAAD\u002ffAAAR3EAAOeAAAB4HgAAlzoAAB9OAACHEwAArA0AAPA8AACIEQAAkzoAAMQJAAA4SAAAOj0AAJc6AAA\u002fHwAAlSYAAGdCAAA\\...\...\\u002fHwAAFGkAABw+AACUEQAAZBkAAFwSAAAwKgAAyBkAAORXAAArAQAACycAAAsnAAAcJQAA9lQAAIc8AADzKgAAqzYAANsuAABoQgAAqzYAAPMqAAAoIwAAvlUAAKQ4AAA4SgAAkzoAAJQRAAA4SgAAbCAAAGhCAAB2FgAApw0AAM8HAAA\\...\u002fcgAAp2EAAHwuAACXOgAAlzoAAHwuAABwFwAAaBAAALYDAABklgAAkBoAAN0iAAB\...\...\...\u002fGAAAMHUAAGQZAAA+FwAAfC4AABIlAAA8cQAAhxMAAAwXAAAPJwAA2A4AAKBBAACHEwAAcBcAAMASAAA+FwAAz60AAKAPAABXGwAAGBUAAPIqAAD0GgAAZu0AAFcSAAA8RgAAOx8AAFgbAAAYRwAATXUAAB4jAACbDwAA\u002f28AAAhSAABuDwAAYC4AAGNCAACUEQAAfJIAAHc+AAByUwAAaEIAANweAACsZgAA7I4AAFSIAADMKQAAdCUAABdOAAB0PgAAjLcAAMx0AADUSQAABEIAAMASAAAgNQAAlBEAACsRAAC8TQAA5FUAAIlQAAAMFwAAuAsAAO5NAAAbTgAA8yoAAMQJAACIEwAA3wwAABYmAAAsZQAASOICAPwIAADUSQAANCEAADwPAAAjIwAAS0YAANQwAAA\...\...\...\...\\...\u002fHwAADBcAAKQGAACoFgAA+CoAALw0AACHEwAA1C4AAKwmAADkJQAAwikAAJM6AADnLAAAi2UAAAsnAACrNgAAkzoAAPMqAABLRgAAwzIAACMjAABLRgAAUxsAAK8ZAABUNgAAZBkAAHAXAADECQAAbg8AAK ...

# %% [markdown]
# ##### 💡 Insight on Price Distribution
# Most vehicles are priced under $20,000, showing that the dataset includes primarily low- to mid-range cars. There's a long tail of expensive listings.
# The histogram reveals that most used vehicles are priced below $20,000, with a sharp drop in frequency as prices increase. A small number of listings exceed $50,000, but they represent rare or luxury vehicles.
#
# This right-skewed distribution indicates that the dataset mostly covers affordable to mid-range vehicles, which aligns with the purpose of the dashboard — to help users explore common pricing trends in the used car market.

# %%
# price vs mileage
px.scatter(df, x='odometer', y='price', color='type')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="76dbd9df-d5b4-477f-ab83-36b75b11fae1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("76dbd9df-d5b4-477f-ab83-36b75b11fae1")) {                    Plotly.newPlot(                        "76dbd9df-d5b4-477f-ab83-36b75b11fae1",                        [{"hovertemplate":"type=SUV\u003cbr\u003eodometer=%{x}\u003cbr\u003eprice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SUV","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"SUV","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAECzAUEAAAAAELr6QAAAAADgbvlAAAAAALj3AUEAAAAA6CUAQQAAAADQk\u002fhAAAAAAFBU\u002f0AAAAAA6AACQQAAAACAzAJBAAAAAAAA+H8AAAAAyMEAQQAAAACATxJBAAAAADhJAkEAAAAAgL7qQAAAAAAAAPh\u002fAAAAAADzBkEAAAAAqJsEQQAAAABQOQFBAAAAABgRB0EAAAAAAAD4fwAAAAAAAPh\u002fAAAAAIC0BkEAAAAAAOBpQAAAAAAAAPh\u002fAAAAACi1BkEAAAAA+JkLQQAAAAAggvlAAAAAAABa30AAAAAA4Gb+QAAAAABAJARBAAAAABgiAUEAAAAAAAD4fwAAAAAQ+fdAAAAAAIBaAkEAAAAAuFgDQQAAAACw8QBBAAAAACCY9kAAAAAAMOb8QAAAAABwdv5AAAAAAKBPCUEAAAAAqIgAQQAAAAAAAPh\u002fAAAAALC790AAAAAAIN\u002f0QAAAAACAtAZBAAAAAADt90AAAAAAYNX\u002fQAAAAAAATdNAAAAAAGAD8UAAAAAAYHnoQAAAAABAKgNBAAAAAMBoA0EAAAAAAAD4fwAAAABQivlAAAAAALDS+UAAAAAAQJUGQQAAAACwWQVBAAAAAMAWAEEAAAAAAFj7QAAAAABAcPhAAAAAAHDa9EAAAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAE3TQAAAAABgA\u002fFAAAAAABBT+0AAAAAAAAD4fwAAAAAAQN9AAAAAAAAA+H8AAAAAAAD4fwAAAACACelAAAAAAABk6UAAAAAAAADZQAAAAAAAAPh\u002fAAAAAABS7EAAAAAAAGrYQAAAAACAGspAAAAAAKBtCEEAAAAAwN8EQQAAAADASANBAAAAAAAA+H8AAAAAwGIEQQAAAADAnv9AAAAAAECtAkEAAAAAAAAAAAAAAAAAAPh\u002fAAAAAADt90AAAAAA8Hb0QAAAAADAwtpAAAAAAJCw+0AAAAAAIA\u002fgQAAAAAA4AwRBAAAAAMAX60AAAAAAIAH9QAAAAAAAAPh\u002fAAAAALjlA0EAAAAA4OgDQQAAAADw8fpAAAAAAAAA+H8AAAAAeDUCQQAAAADAbgJBAAAAAAizAEEAAAAAUMn5QAAAAAAAAPh\u002fAAAAACB+4kAAAAAA0MkFQQAAAAAAAPh\u002fAAAAAABK1kAAAAAA0Kb8QAAAAADAbgJBAAAAANCd+kAAAAAAcGn+QAAAAADgNAdBAAAAADCy\u002fUAAAAAAqKwOQQAAAAAAAPh\u002fAAAAAPCQDkEAAAAAgKgIQQAAAAAAAPh\u002fAAAAAIgSAUEAAAAAAKANQQAAAADAht1AAAAAAKBO+0AAAAAAAMBaQAAAAAAAIGFAAAAAAHBe8kAAAAAAEFX8QAAAAAAAQP9AAAAAAAAA+H8AAAAAMCj0QAAAAAAAAPh\u002fAAAAACiwCkEAAAAAiDUMQQAAAAAAAPh\u002fAAAAAADz9kAAAAAAACj9QAAAAABAlQZBAAAAAAAA+H8AAAAAgIT+QAAAAADg3gZBAAAAAAAC\u002fEAAAAAAgAr+QAAAAABApOFAAAAAABgDAkEAAAAAgIT1QAAAAAAAafRAAAAAACAFAkEAAAAAQH7iQAAAAADQBvtAAAAAAECF0UAAAAAA4JLvQAAAAAAAz\u002fxAAAAAADAt\u002fUAAAAAAAJQRQQAAAAAAEQJBAAAAAABM\u002fUAAAAAAAO26QAAAAAAAAPh\u002fAAAAAMB0AUEAAAAAAOH5QAAAAACAT\u002fJAAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAEAeBUEAAAAA6AsEQQAAAABgrfhAAAAAAMBY20AAAAAAAFPcQAAAAAAAAPh\u002fAAAAAMBiBEEAAAAAQCTkQAAAAADAegBBAAAAAAAA+H8AAAAAAP\u002f0QAAAAACAbAJBAAAAAADJ\u002fUAAAAAAAAD4fwAAAADALwBBAAAAAOAABkEAAAAAYCYMQQAAAADA6wJBAAAAABjABkEAAAAAQJsFQQAAAAAoiAVBAAAAAEBrDUEAAAAAAAX0QAAAAABQjQFBAAAAAABq6EAAAAAAAPLAQAAAAAAAKd5AAAAAAEAo\u002fEAAAAAAwJn8QAAAAACAQ9pAAAAAAMC250AAAAAAiMIEQQAAAAAAIvxAAAAAAHiWB0EAAAAAMJb7QAAAAACAggVBAAAAAAAA+H8AAAAAmIwGQQAAAACggwJBAAAAAAAA+H8AAAAAgGwCQQAAAADAmfxAAAAAAAAA+H8AAAAAcAAAQQAAAAAApP9AAAAAAAAA+H8AAAAAgJb7QAAAAACQpgNBAAAAAIB+\u002f0AAAAAAAP\u002f0QAAAAACAT\u002fJAAAAAAABG\u002fkAAAAAAgJb7QAAAAABAUvNAAAAAAAAA+H8AAAAAwGgDQQAAAAAA+fVAAAAAAMBoA0EAAAAAoDr\u002fQAAAAAAAeuNAAAAAACAuA0EAAAAAAHrjQAAAAABAswFBAAAAAAD5BUEAAAAAQBgGQQAAAAAAAPh\u002fAAAAAOh9AEEAAAAAQCQEQQAAAAAQm\u002fhAAAAAACDL\u002fEAAAAAAAEwNQQAAAAAAAPh\u002fAAAAAAAA+H8AAAAAeBsCQQAAAAAoKgVBAAAAAAAA+H8AAAAAAAQBQQAAAACQovlAAAAAAOCYGEEAAAAAgMAEQQAAAADQYflAAAAAAHilAUEAAAAAwGIEQQAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAXtpAAAAAAGDpBUEAAAAAkJb8QAAAAAAQuvdAAAAAAACIA0EAAAAAAKTjQAAAAAAAAPh\u002fAAAAAAAA+H8AAAAAgD31QAAAAAAAAPh\u002fAAAAAID7\u002f0AAAAAA0Ez1QAAAAACAD\u002fVAAAAAAEAkBEEAAAAAkNn6QAAAAAAAWe1AAAAAAMB6AEEAAAAAsBLzQAAAAADAXAVBAA ...

# %% [markdown]
# #### 💡 Insight on Mileage vs. Price
# There is a clear negative relationship: as mileage increases, price tends to drop. SUVs and trucks show more variance than sedans.
#
# We also observe:
# - A large cluster of affordable vehicles under 200,000 miles
# - A few outliers with extremely high prices or unusually high mileage
# - SUV and truck types tend to show more pricing variability at higher mileages
#
# These insights help support the dashboard's filters and pricing trends for potential buyers.

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

df = df.drop_duplicates()
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# #### 🔁 Duplicate Check
#
# We found **X duplicate rows** in the dataset. These were removed to ensure that the analysis is not skewed by repeated entries.
# This helps improve the accuracy of the visualizations and summary statistics.

# %% [markdown]
# ## ✅ Final Conclusion
#
# This dataset shows expected market behavior — higher mileage leads to lower prices. Most listings are affordable. These insights shaped the layout and filters of the Streamlit dashboard.
#
#  We performed exploratory data analysis (EDA) on a used car sales dataset. The following steps were taken:
#
# - Loaded and inspected the dataset structure
# - Checked for duplicate rows to ensure data quality
# - Created a histogram to visualize the distribution of car prices
# - Created a scatter plot to explore the relationship between mileage and price
#
# #### 🔍 Key Insights:
#
# - Most vehicles are priced below $20,000, indicating that the dataset represents mostly affordable listings.
# - There is a negative correlation between odometer reading and price — vehicles with higher mileage tend to be cheaper.
# - Different vehicle types show varying distributions, with trucks and SUVs sometimes retaining higher value despite mileage.
#
# These insights helped inform the visual layout and filters in the Streamlit dashboard, ensuring that the final web app clearly highlights pricing patterns and market behavior.
